# %%
test_bytes = b''

# %%
import numpy as np

# %%
print(len(test_bytes))

# %%
end = 4 + int.from_bytes(test_bytes[0:4], byteorder="big")
print(end)

# %%
import json

# %%
command = json.loads(test_bytes[4:end].decode("utf-8"))
print(command)

# %%
test_bytes[end:]

# %%
length =len(test_bytes[end:])
print(length, length%4)

# %%
from util.util import mp4_bytes_to_ndarray, ndarray_to_mp4_bytes


payload = test_bytes[end:]
print(len(payload))
audio = mp4_bytes_to_ndarray(payload, 16000)
audio = ndarray_to_mp4_bytes(audio, 16000)
audio = mp4_bytes_to_ndarray(audio, 16000)

# %%
audio.shape

# %%
from IPython.display import Audio

# %%
Audio(audio, rate=16000)
